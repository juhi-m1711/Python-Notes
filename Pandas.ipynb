# %%
import pandas as pd

# %% [markdown]
# 1. Series

# %%
s = pd.Series(["a","b","c","d","e"], index = [1,2,3,4,5])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
s2 = pd.Series({1:12, 2:34, 3:45, 4:32})

# %%
type(s2)
# Out:
# pandas.core.series.Series

# %%
s2
# Out:
# 1    12
# 2    34
# 3    45
# 4    32
# dtype: int64

# %%
s3 = pd.Series([3.14, 2.17], name = "constants")

# %%
s3
# Out:
# 0    3.14
# 1    2.17
# Name: constants, dtype: float64

# %% [markdown]
# 2. DataFrame

# %%
d = pd.DataFrame({
    "Id" : [1, 2, 3, 4],
    "Name" : ["Juhi", "Aryan", "Nisha", "Sara"]
})

# %%
d
# Out:
#    Id   Name
# 0   1   Juhi
# 1   2  Aryan
# 2   3  Nisha
# 3   4   Sara

# %%
df = pd.read_csv("employees.csv")

# %%
df
# Out:
#        EEID               Job Title  Department        Business Unit  Gender  \
# 0    E93810     Technical Architect          IT  Speciality Products    Male
# 1    E13905     Technical Architect     Finance        Manufacturing    Male
# 2    E10851                Director   Marketing            Corporate  Female
# 3    E57052  Account Representative  Operations  Speciality Products    Male
# 4    E92397  Account Representative  Operations        Manufacturing    Male
# ..      ...                     ...         ...                  ...     ...
# 495  E94465                 Analyst          HR        Manufacturing    Male
# 496  E97186  Account Representative       Sales            Corporate  Female
# 497  E46996  Account Representative  Operations        Manufacturing    Male
# 498  E62535                 Manager     Finance        Manufacturing    Male
# 499  E67062  Account Representative  Operations        Manufacturing    Male
#
# ...

# %%
df[df["Age"] <25]
# Out:
#        EEID                 Job Title  Department           Business Unit  \
# 16   E10942       Technical Architect   Marketing  Research & Development
# 29   E29536               Sr. Manager       Sales           Manufacturing
# 39   E40784               Sr. Analyst     Finance           Manufacturing
# 49   E59692               Sr. Analyst          HR     Speciality Products
# 61   E35443               Sr. Analyst     Finance     Speciality Products
# 62   E82529               Sr. Analyst   Marketing           Manufacturing
# 66   E30517               Sr. Manager          HR               Corporate
# 74   E81987                  Director       Sales               Corporate
# 80   E87356    Account Representative          IT               Corporate
# 113  E37686                  Director       Sales     Speciality Products
# 114  E40161    Account Representative          IT               Corporate
# 125  E59372    Account Representative     Finance  Research & Development
# ...

# %%
df.describe()
# Out:
#               Age  Annual Salary     Bonus %
# count  500.000000      500.00000  500.000000
# mean    44.050000   109228.28380    0.098400
# std     13.060346    39933.49392    0.072719
# min     22.000000    40219.01000    0.000000
# 25%     32.000000    74583.99500    0.050000
# 50%     45.000000   108325.72500    0.100000
# 75%     56.000000   143233.04500    0.150000
# max     65.000000   179912.30000    0.200000

# %%
b = df[df["Age"] <25]

# %%
b.shape
# Out:
# (36, 13)

# %%
df.shape
# Out:
# (500, 13)

# %%
df[0:11]
# Out:
#       EEID                 Job Title  Department        Business Unit  Gender  \
# 0   E93810       Technical Architect          IT  Speciality Products    Male
# 1   E13905       Technical Architect     Finance        Manufacturing    Male
# 2   E10851                  Director   Marketing            Corporate  Female
# 3   E57052    Account Representative  Operations  Speciality Products    Male
# 4   E92397    Account Representative  Operations        Manufacturing    Male
# 5   E59823               Sr. Analyst          HR  Speciality Products    Male
# 6   E32431  Computer Systems Manager     Finance            Corporate  Female
# 7   E17331  Computer Systems Manager          IT  Speciality Products  Female
# 8   E75435                   Manager   Marketing            Corporate    Male
# 9   E66155                   Manager       Sales        Manufacturing    Male
# 10  E65333       Technical Architect          HR            Corporate  Female
#
# ...

# %%
df["Bonus Amount"] = df["Annual Salary"] * 0.2

# %%
df
# Out:
#        EEID               Job Title  Department        Business Unit  Gender  \
# 0    E93810     Technical Architect          IT  Speciality Products    Male
# 1    E13905     Technical Architect     Finance        Manufacturing    Male
# 2    E10851                Director   Marketing            Corporate  Female
# 3    E57052  Account Representative  Operations  Speciality Products    Male
# 4    E92397  Account Representative  Operations        Manufacturing    Male
# ..      ...                     ...         ...                  ...     ...
# 495  E94465                 Analyst          HR        Manufacturing    Male
# 496  E97186  Account Representative       Sales            Corporate  Female
# 497  E46996  Account Representative  Operations        Manufacturing    Male
# 498  E62535                 Manager     Finance        Manufacturing    Male
# 499  E67062  Account Representative  Operations        Manufacturing    Male
#
# ...

# %%
df["Total Salary"] = df["Annual Salary"] + df["Bonus Amount"]

# %%
df
# Out:
#        EEID               Job Title  Department        Business Unit  Gender  \
# 0    E93810     Technical Architect          IT  Speciality Products    Male
# 1    E13905     Technical Architect     Finance        Manufacturing    Male
# 2    E10851                Director   Marketing            Corporate  Female
# 3    E57052  Account Representative  Operations  Speciality Products    Male
# 4    E92397  Account Representative  Operations        Manufacturing    Male
# ..      ...                     ...         ...                  ...     ...
# 495  E94465                 Analyst          HR        Manufacturing    Male
# 496  E97186  Account Representative       Sales            Corporate  Female
# 497  E46996  Account Representative  Operations        Manufacturing    Male
# 498  E62535                 Manager     Finance        Manufacturing    Male
# 499  E67062  Account Representative  Operations        Manufacturing    Male
#
# ...

# %%
df.sort_values(by="Department", ascending=True, inplace = True)

# %%
df
# Out:
#        EEID               Job Title  Department        Business Unit  Gender  \
# 0    E93810     Technical Architect          IT  Speciality Products    Male
# 1    E13905     Technical Architect     Finance        Manufacturing    Male
# 2    E10851                Director   Marketing            Corporate  Female
# 3    E57052  Account Representative  Operations  Speciality Products    Male
# 4    E92397  Account Representative  Operations        Manufacturing    Male
# ..      ...                     ...         ...                  ...     ...
# 495  E94465                 Analyst          HR        Manufacturing    Male
# 496  E97186  Account Representative       Sales            Corporate  Female
# 497  E46996  Account Representative  Operations        Manufacturing    Male
# 498  E62535                 Manager     Finance        Manufacturing    Male
# 499  E67062  Account Representative  Operations        Manufacturing    Male
#
# ...

# %%
df.head(5)
# Out:
#      EEID               Job Title  Department        Business Unit  Gender  \
# 0  E93810     Technical Architect          IT  Speciality Products    Male
# 1  E13905     Technical Architect     Finance        Manufacturing    Male
# 2  E10851                Director   Marketing            Corporate  Female
# 3  E57052  Account Representative  Operations  Speciality Products    Male
# 4  E92397  Account Representative  Operations        Manufacturing    Male
#
#    Ethnicity  Age   Hire Date  Annual Salary  Bonus %        Country  \
# 0      Asian   30  30-11-2016      143105.97     0.20  United States
# 1      Asian   63  12-12-1998      138185.50     0.15         Canada
# 2  Caucasian   31  04-01-1996       70143.93     0.10  United States
# 3   Hispanic   56  22-05-2020       57475.66     0.15  United States
# 4      Black   64  29-06-2003       71905.76     0.10  United States
#
#         City   Exit Date  Bonus Amount  Total Salary
# ...

# %%
df.tail(2)
# Out:
#        EEID               Job Title  Department  Business Unit Gender  \
# 498  E62535                 Manager     Finance  Manufacturing   Male
# 499  E67062  Account Representative  Operations  Manufacturing   Male
#
#     Ethnicity  Age   Hire Date  Annual Salary  Bonus %    Country       City  \
# 498  Hispanic   46  29-01-2001       49248.39     0.05  Australia  Melbourne
# 499     Black   58  07-02-2016      157144.75     0.00    Germany     Munich
#
#     Exit Date  Bonus Amount  Total Salary
# 498       NaN      9849.678     59098.068
# 499       NaN     31428.950    188573.700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           500 non-null    object
#  1   Job Title      500 non-null    object
#  2   Department     500 non-null    object
#  3   Business Unit  500 non-null    object
#  4   Gender         500 non-null    object
#  5   Ethnicity      500 non-null    object
#  6   Age            500 non-null    int64
#  7   Hire Date      500 non-null    object
#  8   Annual Salary  500 non-null    float64
#  9   Bonus %        500 non-null    float64
#  10  Country        500 non-null    object
#  11  City           500 non-null    object
#  12  Exit Date      152 non-null    object
#  13  Bonus Amount   500 non-null    float64
#  14  Total Salary   500 non-null    float64
# dtypes: float64(4), int64(1), object(10)
# memory usage: 58.7+ KB
