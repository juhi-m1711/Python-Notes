# %%
import pandas as pd

# %%
sales = pd.read_csv("Book1.csv")

# %%
sales
# Out:
#     OrderID       Date Region   SalesPerson   Product  Quantity  UnitPrice  \
# 0       101  1/10/2024  North  Rahul Sharma    Laptop         2      55000
# 1       102  1/12/2024  South   Priya Mehta  Keyboard         5       1200
# 2       103  1/14/2024   West    Anil Verma     Mouse        10        700
# 3       104  1/18/2024   East    Riya Patel   Monitor         3      15000
# 4       105  1/20/2024  North  Rahul Sharma    Laptop         1      55000
# 5       106  1/22/2024  South   Priya Mehta     Mouse        15        700
# 6       107  1/25/2024   West    Anil Verma   Monitor         2      15000
# 7       108   2/1/2024   East    Riya Patel    Laptop         3      55000
# 8       109   2/3/2024  North  Rahul Sharma     Mouse        20        700
# 9       110   2/7/2024  South   Priya Mehta    Laptop         2      55000
# 10      111   2/8/2024   West    Anil Verma  Keyboard        10       1200
# ...

# %%
sales.rename(columns = {"SalesPerson": "SalesMan"}, inplace= True)

# %%
sales
# Out:
#     OrderID       Date Region      SalesMan   Product  Quantity  UnitPrice  \
# 0       101  1/10/2024  North  Rahul Sharma    Laptop         2      55000
# 1       102  1/12/2024  South   Priya Mehta  Keyboard         5       1200
# 2       103  1/14/2024   West    Anil Verma     Mouse        10        700
# 3       104  1/18/2024   East    Riya Patel   Monitor         3      15000
# 4       105  1/20/2024  North  Rahul Sharma    Laptop         1      55000
# 5       106  1/22/2024  South   Priya Mehta     Mouse        15        700
# 6       107  1/25/2024   West    Anil Verma   Monitor         2      15000
# 7       108   2/1/2024   East    Riya Patel    Laptop         3      55000
# 8       109   2/3/2024  North  Rahul Sharma     Mouse        20        700
# 9       110   2/7/2024  South   Priya Mehta    Laptop         2      55000
# 10      111   2/8/2024   West    Anil Verma  Keyboard        10       1200
# ...

# %%
sales.replace({"North": "N", "South": "S", "East": "E", "West": "W"}, inplace = True)

# %%
sales
# Out:
#     OrderID       Date Region      SalesMan   Product  Quantity  UnitPrice  \
# 0       101  1/10/2024      N  Rahul Sharma    Laptop         2      55000
# 1       102  1/12/2024      S   Priya Mehta  Keyboard         5       1200
# 2       103  1/14/2024      W    Anil Verma     Mouse        10        700
# 3       104  1/18/2024      E    Riya Patel   Monitor         3      15000
# 4       105  1/20/2024      N  Rahul Sharma    Laptop         1      55000
# 5       106  1/22/2024      S   Priya Mehta     Mouse        15        700
# 6       107  1/25/2024      W    Anil Verma   Monitor         2      15000
# 7       108   2/1/2024      E    Riya Patel    Laptop         3      55000
# 8       109   2/3/2024      N  Rahul Sharma     Mouse        20        700
# 9       110   2/7/2024      S   Priya Mehta    Laptop         2      55000
# 10      111   2/8/2024      W    Anil Verma  Keyboard        10       1200
# ...

# %%
sales.loc[0:5, ['SalesMan', 'Quantity', 'UnitPrice']]
# Out:
#        SalesMan  Quantity  UnitPrice
# 0  Rahul Sharma         2      55000
# 1   Priya Mehta         5       1200
# 2    Anil Verma        10        700
# 3    Riya Patel         3      15000
# 4  Rahul Sharma         1      55000
# 5   Priya Mehta        15        700

# %%
sales.iloc[0:6, 3:6]
# Out:
#        SalesMan   Product  Quantity
# 0  Rahul Sharma    Laptop         2
# 1   Priya Mehta  Keyboard         5
# 2    Anil Verma     Mouse        10
# 3    Riya Patel   Monitor         3
# 4  Rahul Sharma    Laptop         1
# 5   Priya Mehta     Mouse        15

# %%
sales.loc[sales['Quantity'] > 5, 'Quantity'] = 10

# %%
sales
# Out:
#     OrderID       Date Region      SalesMan   Product  Quantity  UnitPrice  \
# 0       101  1/10/2024      N  Rahul Sharma    Laptop         5      55000
# 1       102  1/12/2024      S   Priya Mehta  Keyboard         5       1200
# 2       103  1/14/2024      W    Anil Verma     Mouse        10        700
# 3       104  1/18/2024      E    Riya Patel   Monitor         5      15000
# 4       105  1/20/2024      N  Rahul Sharma    Laptop         5      55000
# 5       106  1/22/2024      S   Priya Mehta     Mouse        10        700
# 6       107  1/25/2024      W    Anil Verma   Monitor         5      15000
# 7       108   2/1/2024      E    Riya Patel    Laptop         5      55000
# 8       109   2/3/2024      N  Rahul Sharma     Mouse        10        700
# 9       110   2/7/2024      S   Priya Mehta    Laptop         5      55000
# 10      111   2/8/2024      W    Anil Verma  Keyboard        10       1200
# ...
