# %% [markdown]
# Split and Join Function

# %%
f = "Banana Mango"
f
# Out:
# 'Banana Mango'

# %%
f.split(" ") #breaks a string into a list.
# Out:
# ['Banana', 'Mango']

# %%
f2 = f.split(" ")

# %%
" ".join(f2)
# Out:
# 'Banana Mango'
