# %% [markdown]
# # String(Indexing, Slicing, Steps)

# %%
name = "Python"

# %%
type(name)
# Out:
# str

# %% [markdown]
# #Indexing

# %%
name[0]
# Out:
# 'P'

# %%
name[5]
# Out:
# 'n'

# %%
name[-2]
# Out:
# 'o'

# %% [markdown]
# #Slicing

# %%
name[0:4]
# Out:
# 'Pyth'

# %%
name[0:]
# Out:
# 'Python'

# %%
name[-4:-1]
# Out:
# 'tho'

# %%
name[:-1]
# Out:
# 'Pytho'

# %%
name[:3]
# Out:
# 'Pyt'

# %% [markdown]
# #Steps

# %%
name[::2] #Skips every second letter
# Out:
# 'Pto'

# %%
name[0:4:2] #Starts from 0 index no. to 4 index number, skipping every 2nd letter
# Out:
# 'Pt'

# %%
name[5:0:-1]
# Out:
# 'nohty'

# %%
name[5::-1]
# Out:
# 'nohtyP'

# %%
lang = "programming"

# %%
lang[1:]
# Out:
# 'rogramming'

# %%
"P" + lang[1:] #Capitalizing letter using Slicing
# Out:
# 'Programming'

# %%
n = "My name is juhi"

# %%
n
# Out:
# 'My name is juhi'

# %%
new_n = n[0:11] + "J" + n[12:] + " Moudekar"

# %%
new_n
# Out:
# 'My name is Juhi Moudekar'
