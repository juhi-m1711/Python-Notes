# %% [markdown]
# #Find And Replace Function

# %%
n = "Data Analysis"

# %%
n
# Out:
# 'Data Analysis'

# %%
n.find("i") #finds the index number of the first appearance of a character.
# Out:
# 11

# %%
n.replace("Data", "Business") #replaces.
# Out:
# 'Business Analysis'

# %%
n.find("na")
# Out:
# 6
