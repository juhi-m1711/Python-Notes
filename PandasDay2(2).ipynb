# %%
import pandas as pd

# %%
import numpy as np

# %%
sales = pd.read_csv("Book1.csv")

# %%
sales
# Out:
#     OrderID       Date Region   SalesPerson   Product  Quantity  UnitPrice  \
# 0       101  1/10/2024  North  Rahul Sharma    Laptop         2      55000
# 1       102  1/12/2024  South   Priya Mehta  Keyboard         5       1200
# 2       103  1/14/2024   West    Anil Verma     Mouse        10        700
# 3       104  1/18/2024   East    Riya Patel   Monitor         3      15000
# 4       105  1/20/2024  North  Rahul Sharma    Laptop         1      55000
# 5       106  1/22/2024  South   Priya Mehta     Mouse        15        700
# 6       107  1/25/2024   West    Anil Verma   Monitor         2      15000
# 7       108   2/1/2024   East    Riya Patel    Laptop         3      55000
# 8       109   2/3/2024  North  Rahul Sharma     Mouse        20        700
# 9       110   2/7/2024  South   Priya Mehta    Laptop         2      55000
# 10      111   2/8/2024   West    Anil Verma  Keyboard        10       1200
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      20 non-null     int64
#  1   Date         20 non-null     object
#  2   Region       20 non-null     object
#  3   SalesPerson  20 non-null     object
#  4   Product      20 non-null     object
#  5   Quantity     20 non-null     int64
#  6   UnitPrice    20 non-null     int64
#  7   Discount     20 non-null     float64
#  8   TotalAmount  20 non-null     int64
#  9   Category     20 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 1.7+ KB

# %%
sales.loc[sales["Discount"] > 0.05, "Discount_Type"] = "High Discount"
sales.loc[sales["Discount"] <= 0.05, "Discount_Type"] = "Low Discount"

# %%
sales
# Out:
#     OrderID       Date Region   SalesPerson   Product  Quantity  UnitPrice  \
# 0       101  1/10/2024  North  Rahul Sharma    Laptop         2      55000
# 1       102  1/12/2024  South   Priya Mehta  Keyboard         5       1200
# 2       103  1/14/2024   West    Anil Verma     Mouse        10        700
# 3       104  1/18/2024   East    Riya Patel   Monitor         3      15000
# 4       105  1/20/2024  North  Rahul Sharma    Laptop         1      55000
# 5       106  1/22/2024  South   Priya Mehta     Mouse        15        700
# 6       107  1/25/2024   West    Anil Verma   Monitor         2      15000
# 7       108   2/1/2024   East    Riya Patel    Laptop         3      55000
# 8       109   2/3/2024  North  Rahul Sharma     Mouse        20        700
# 9       110   2/7/2024  South   Priya Mehta    Laptop         2      55000
# 10      111   2/8/2024   West    Anil Verma  Keyboard        10       1200
# ...

# %%
sales["Quantity"].sum()
# Out:
# np.int64(121)

# %%
product_sales = sales.groupby("Product")["TotalAmount"].sum()

# %%
product_sales
# Out:
# Product
# Keyboard     40080
# Laptop      858000
# Monitor     114000
# Mouse        39550
# Name: TotalAmount, dtype: int64

# %%
pivots = pd.pivot_table(sales,
                        values = "TotalAmount",
                        index = "Region",
                        columns = "Product",
                        aggfunc = "sum")

# %%
pivots
# Out:
# Product  Keyboard    Laptop  Monitor    Mouse
# Region
# East      14460.0  148500.0  55500.0      NaN
# North      9120.0  154000.0  30000.0  12600.0
# South      5700.0  357500.0      NaN  16450.0
# West      10800.0  198000.0  28500.0  10500.0

# %%
pd.crosstab(sales['Region'], sales['Category'])
# Out:
# Category  Accessories  Electronics
# Region
# East                2            3
# North               2            3
# South               3            2
# West                3            2

# %%
sales.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
sales.drop_duplicates(inplace = True)

# %%
sales
# Out:
#     OrderID       Date Region   SalesPerson   Product  Quantity  UnitPrice  \
# 0       101  1/10/2024  North  Rahul Sharma    Laptop         2      55000
# 1       102  1/12/2024  South   Priya Mehta  Keyboard         5       1200
# 2       103  1/14/2024   West    Anil Verma     Mouse        10        700
# 3       104  1/18/2024   East    Riya Patel   Monitor         3      15000
# 4       105  1/20/2024  North  Rahul Sharma    Laptop         1      55000
# 5       106  1/22/2024  South   Priya Mehta     Mouse        15        700
# 6       107  1/25/2024   West    Anil Verma   Monitor         2      15000
# 7       108   2/1/2024   East    Riya Patel    Laptop         3      55000
# 8       109   2/3/2024  North  Rahul Sharma     Mouse        20        700
# 9       110   2/7/2024  South   Priya Mehta    Laptop         2      55000
# 10      111   2/8/2024   West    Anil Verma  Keyboard        10       1200
# ...

# %%
data = {
    "EmployeeID": [101, 102, 103, 104, 105],
    "Name": ["Rahul", "Priya", "Amit", "Sneha", "Karan"],
    "Department": ["Sales", "HR", "IT", np.nan, "Marketing"],
    "Salary": [50000, np.nan, 65000, 48000, np.nan],
    "Experience": [3, 5, np.nan, 2, 4]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    EmployeeID   Name Department   Salary  Experience
# 0         101  Rahul      Sales  50000.0         3.0
# 1         102  Priya         HR      NaN         5.0
# 2         103   Amit         IT  65000.0         NaN
# 3         104  Sneha        NaN  48000.0         2.0
# 4         105  Karan  Marketing      NaN         4.0

# %%
df.isnull()
# Out:
#    EmployeeID   Name  Department  Salary  Experience
# 0       False  False       False   False       False
# 1       False  False       False    True       False
# 2       False  False       False   False        True
# 3       False  False        True   False       False
# 4       False  False       False    True       False

# %%
df.notnull()
# Out:
#    EmployeeID  Name  Department  Salary  Experience
# 0        True  True        True    True        True
# 1        True  True        True   False        True
# 2        True  True        True    True       False
# 3        True  True       False    True        True
# 4        True  True        True   False        True

# %%
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          0
# Department    1
# Salary        2
# Experience    1
# dtype: int64

# %%
df.count()
# Out:
# EmployeeID    5
# Name          5
# Department    4
# Salary        3
# Experience    4
# dtype: int64

# %%
df.count(axis = 1)
# Out:
# 0    5
# 1    4
# 2    4
# 3    4
# 4    4
# dtype: int64

# %%
df.dropna()
# Out:
#    EmployeeID   Name Department   Salary  Experience
# 0         101  Rahul      Sales  50000.0         3.0

# %%
df.dropna(axis = 1)
# Out:
#    EmployeeID   Name
# 0         101  Rahul
# 1         102  Priya
# 2         103   Amit
# 3         104  Sneha
# 4         105  Karan

# %%
df.dropna(thresh = 3)
# Out:
#    EmployeeID   Name Department   Salary  Experience
# 0         101  Rahul      Sales  50000.0         3.0
# 1         102  Priya         HR      NaN         5.0
# 2         103   Amit         IT  65000.0         NaN
# 3         104  Sneha        NaN  48000.0         2.0
# 4         105  Karan  Marketing      NaN         4.0

# %%
df.fillna(0)
# Out:
#    EmployeeID   Name Department   Salary  Experience
# 0         101  Rahul      Sales  50000.0         3.0
# 1         102  Priya         HR      0.0         5.0
# 2         103   Amit         IT  65000.0         0.0
# 3         104  Sneha          0  48000.0         2.0
# 4         105  Karan  Marketing      0.0         4.0

# %%
df["Salary"].fillna(df["Salary"].mean(), inplace = True)
# Out:
# C:\Users\juhim\AppData\Local\Temp\ipykernel_19420\1868925770.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Salary"].fillna(df["Salary"].mean(), inplace = True)

# %%
df
# Out:
#    EmployeeID   Name Department        Salary  Experience
# 0         101  Rahul      Sales  50000.000000         3.0
# 1         102  Priya         HR  54333.333333         5.0
# 2         103   Amit         IT  65000.000000         NaN
# 3         104  Sneha        NaN  48000.000000         2.0
# 4         105  Karan  Marketing  54333.333333         4.0

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\juhim\AppData\Local\Temp\ipykernel_19420\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#    EmployeeID   Name Department        Salary  Experience
# 0         101  Rahul      Sales  50000.000000         3.0
# 1         102  Priya         HR  54333.333333         5.0
# 2         103   Amit         IT  65000.000000         5.0
# 3         104  Sneha         IT  48000.000000         2.0
# 4         105  Karan  Marketing  54333.333333         4.0

# %%
df.fillna(method="bfill")
# Out:
# C:\Users\juhim\AppData\Local\Temp\ipykernel_19420\3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#    EmployeeID   Name Department        Salary  Experience
# 0         101  Rahul      Sales  50000.000000         3.0
# 1         102  Priya         HR  54333.333333         5.0
# 2         103   Amit         IT  65000.000000         2.0
# 3         104  Sneha  Marketing  48000.000000         2.0
# 4         105  Karan  Marketing  54333.333333         4.0

# %%
df.ffill()
# Out:
#    EmployeeID   Name Department        Salary  Experience
# 0         101  Rahul      Sales  50000.000000         3.0
# 1         102  Priya         HR  54333.333333         5.0
# 2         103   Amit         IT  65000.000000         5.0
# 3         104  Sneha         IT  48000.000000         2.0
# 4         105  Karan  Marketing  54333.333333         4.0

# %%
df.bfill()
# Out:
#    EmployeeID   Name Department        Salary  Experience
# 0         101  Rahul      Sales  50000.000000         3.0
# 1         102  Priya         HR  54333.333333         5.0
# 2         103   Amit         IT  65000.000000         2.0
# 3         104  Sneha  Marketing  48000.000000         2.0
# 4         105  Karan  Marketing  54333.333333         4.0
