# %% [markdown]
# String Functions

# %%
a = "Data Analysis"

# %%
len(a) #Counts the lenght of a string
# Out:
# 13

# %%
a.upper() #UPPERCASE
# Out:
# 'DATA ANALYSIS'

# %%
a.lower() #LOWERCASE
# Out:
# 'data analysis'

# %%
a.capitalize() #Capitalize only the first letter of a sentence
# Out:
# 'Data analysis'

# %%
a.title() #Capitalize the first letter of each word in a setence
# Out:
# 'Data Analysis'
