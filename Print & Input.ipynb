# %%
print("Jupyter")
# Out:
# Jupyter

# %%
name = input("enter your name:")
print("My name is ", name)
# Out:
# enter your name: Juhi
# My name is  Juhi

# %%
# My name is __ and I am from ___.
name = input("enter your name:")
city = input("enter the city you live in:")
print("My name is", name,"and I am from", city)
# Out:
# enter your name: Juhi
# enter the city you live in: Nagpur
# My name is Juhi and I am from Nagpur

# %%
# Sum of two numbers
x = int(input("Enter a number:"))
y = int(input("Enter another number:"))
print("Sum:", x+y)
# Out:
# Enter a number: 5
# Enter another number: 6
# Sum: 11
