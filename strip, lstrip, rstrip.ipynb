# %% [markdown]
# Strip, Lstrip, and Rstrip Function

# %%
msg = "         Hello World            "

# %%
msg
# Out:
# '         Hello World            '

# %%
msg.strip() # Removes leading and trailing spaces.
# Out:
# 'Hello World'

# %%
msg.lstrip() # Removes spaces from the left
# Out:
# 'Hello World            '

# %%
msg.rstrip() # Removes spaces from the right
# Out:
# '         Hello World'
